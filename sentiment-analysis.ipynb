# %%
from utils import load_corpus, stopwords
import numpy as np
from torch.utils.tensorboard.writer import SummaryWriter
import os
import datetime

# %%
TRAIN_PATH = "../weibo2018/train.txt"
TEST_PATH = "../weibo2018/test.txt"

# 分别加载训练集和测试集
train_data = load_corpus(TRAIN_PATH)
test_data = load_corpus(TEST_PATH)

today = datetime.date.today().strftime('%Y%m%d')
if not os.path.exists('./evaluation'):
    os.makedirs('./evaluation')
writer = SummaryWriter(log_dir=os.path.join('./evaluation', today))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.625 seconds.
# Prefix dict has been built successfully.

# %%
os.path.join('/evaluation', today)
# Out:
# '/evaluation/20220208'

# %%
import pandas as pd

df_train = pd.DataFrame(train_data, columns=["text", "label"])
df_test = pd.DataFrame(test_data, columns=["text", "label"])
df_train.head()
# Out:
#                                                 text  label
# 0  书中 自有 黄金屋 书中 自有 颜如玉 沿着 岁月 的 长河 跋涉 或是 风光旖旎 或是 姹...      1
# 1  这是 英超 被 黑 的 最惨 的 一次 二哈 二哈 十几年来 中国 只有 孙继海 董方卓 郑...      0
# 2  中国 远洋 海运 集团 副总经理 俞曾 港 月 日 在 上 表示 中央 企业 走 出去 是 ...      1
# 3  看 流星花园 其实 也 还好 啦 现在 的 观念 以及 时尚 眼光 都 不一样 了 或许 十...      1
# 4  汉武帝 的 罪己 诏 的 真实性 尽管 存在 着 争议 然而 轮台 罪己 诏 作为 中国 历...      1

# %%
# word2vec要求的输入格式: list(word)
wv_input = df_train['text'].map(lambda s: s.split(" "))   # [for w in s.split(" ") if w not in stopwords]
wv_input.head()
# Out:
# 0    [书中, 自有, 黄金屋, 书中, 自有, 颜如玉, 沿着, 岁月, 的, 长河, 跋涉, ...
# 1    [这是, 英超, 被, 黑, 的, 最惨, 的, 一次, 二哈, 二哈, 十几年来, 中国,...
# 2    [中国, 远洋, 海运, 集团, 副总经理, 俞曾, 港, 月, 日, 在, 上, 表示, ...
# 3    [看, 流星花园, 其实, 也, 还好, 啦, 现在, 的, 观念, 以及, 时尚, 眼光,...
# 4    [汉武帝, 的, 罪己, 诏, 的, 真实性, 尽管, 存在, 着, 争议, 然而, 轮台,...
# Name: text, dtype: object

# %%
from gensim import models

# Word2Vec
word2vec = models.Word2Vec(wv_input, 
                           vector_size=128,   # 词向量维度
                           min_count=1,      # 最小词频, 因为数据量较小, 这里卡1
                           epochs=1000)      # 迭代轮次
# Out:
# /opt/conda/envs/june_env/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
word2vec.wv.most_similar("你")
# Out:
# [('我', 0.9512325525283813),
#  ('他', 0.8914921879768372),
#  ('的', 0.8785059452056885),
#  ('自己', 0.8765919208526611),
#  ('了', 0.8479840159416199),
#  ('都', 0.8261860609054565),
#  ('人', 0.8194601535797119),
#  ('是', 0.8069769740104675),
#  ('也', 0.7970981001853943),
#  ('就', 0.7916268110275269)]

# %%
word2vec.wv.most_similar("汽车")
# Out:
# [('燃料电池', 0.4654559791088104),
#  ('新能源', 0.4610259532928467),
#  ('王哲', 0.45301851630210876),
#  ('长椅', 0.4285859763622284),
#  ('加增', 0.42834678292274475),
#  ('怨气', 0.42726951837539673),
#  ('挖掘机', 0.4267406463623047),
#  ('柬埔寨', 0.4071280360221863),
#  ('轮船', 0.4057103395462036),
#  ('合婚', 0.40410640835762024)]

# %%
import torch
from torch import nn
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence,pad_packed_sequence
from torch.utils.data import Dataset, DataLoader

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
# 超参数
learning_rate = 5e-6
input_size = 768
num_epoches = 100
batch_size = 128
embed_size = 128
hidden_size = 64
num_layers = 2

# %%
# 数据集
class MyDataset(Dataset):
    def __init__(self, df):
        self.data = []
        self.label = df["label"].tolist()
        for s in df["text"].tolist():
            vectors = []
            for w in s.split(" "):
                if w in word2vec.wv.key_to_index:
                    vectors.append(word2vec.wv[w])   # 将每个词替换为对应的词向量
            vectors = torch.Tensor(vectors)
            self.data.append(vectors)
    
    def __getitem__(self, index):
        data = self.data[index]
        label = self.label[index]
        return data, label

    def __len__(self):
        return len(self.label)

def collate_fn(data):
    """
    :param data: 第0维：data，第1维：label
    :return: 序列化的data、记录实际长度的序列、以及label列表
    """
    data.sort(key=lambda x: len(x[0]), reverse=True) # pack_padded_sequence要求要按照序列的长度倒序排列
    data_length = [len(sq[0]) for sq in data]
    x = [i[0] for i in data]
    y = [i[1] for i in data]
    data = pad_sequence(x, batch_first=True, padding_value=0)   # 用RNN处理变长序列的必要操作
    return data, torch.tensor(y, dtype=torch.float32), torch.tensor(data_length)


# 训练集
train_data = MyDataset(df_train)
train_loader = DataLoader(train_data, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)

# 测试集
test_data = MyDataset(df_test)
test_loader = DataLoader(test_data, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)

# %%
# 网络结构
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 1)  # 双向, 输出维度要*2
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, lengths):
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(device)  # 双向, 第一个维度要*2
        c0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(device)
        
        packed_input = torch.nn.utils.rnn.pack_padded_sequence(input=x, lengths=lengths, batch_first=True)
        
        packed_out, (h_n, h_c) = self.lstm(packed_input, (h0, c0))

        lstm_out = torch.cat([h_n[-2], h_n[-1]], 1)  # 双向, 所以要将最后两维拼接, 得到的就是最后一个time step的输出
        out = self.fc(lstm_out)
        out = self.sigmoid(out)
        return out

lstm = LSTM(embed_size, hidden_size, num_layers).to(device)

# %%
from sklearn import metrics

# 在测试集效果检验
def test(epoch,num_epoches):
    y_pred, y_true = [], []

    with torch.no_grad():
        for x, labels, lengths in test_loader:
            x = x.to(device)
            outputs = lstm(x, lengths)         # 前向传播
            outputs = outputs.view(-1)          # 将输出展平
            y_pred.append(outputs)
            y_true.append(labels)

    y_prob = torch.cat(y_pred).cpu()
    y_true = torch.cat(y_true).cpu()
    y_pred = y_prob.clone()
    y_pred[y_pred > 0.5] = 1
    y_pred[y_pred <= 0.5] = 0
    
    precision, recall, f1, _ = metrics.precision_recall_fscore_support(y_true, y_pred)
    roc_auc = metrics.roc_auc_score(y_true, y_prob)
    # print(metrics.classification_report(y_true, y_pred))
    # print("测试集准确率:", metrics.accuracy_score(y_true, y_pred))
    # print("测试集AUC:", metrics.roc_auc_score(y_true, y_prob) )
    print('f1',f1)
    print('Epoch {}/{}, P {:.4f}, R {:.4f}, F {:.4f}, AUC {:.4f}'.format(
        epoch, num_epoches, precision.mean(), recall.mean(), f1.mean(), roc_auc.mean()))
    writer.add_scalar('precision', precision.mean(), epoch)
    writer.add_scalar('recall', recall.mean(), epoch)
    writer.add_scalar('f1score', f1.mean(), epoch)
    writer.add_scalar('auc', roc_auc.mean(), epoch)

# %%
# 定义损失函数和优化器
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)

# %%
# 迭代训练
for epoch in range(num_epoches):
    total_loss = 0
    for i, (x, labels, lengths) in enumerate(train_loader):
        x = x.to(device)
        labels = labels.to(device)
        outputs = lstm(x, lengths)          # 前向传播
        logits = outputs.view(-1)           # 将输出展平
        loss = criterion(logits, labels)    # loss计算
        total_loss += loss
        optimizer.zero_grad()               # 梯度清零
        loss.backward(retain_graph=True)    # 反向传播，计算梯度
        optimizer.step()                    # 梯度更新
        if (i+1) % 50 == 0:
            print("epoch:{}, step:{}, loss:{}".format(epoch+1, i+1, total_loss/10))
            total_loss = 0
    writer.add_scalar('train_loss', total_loss, epoch)
    # test
    test(epoch,num_epoches)
    
    # save model
    model_path = "./model/lstm_{}.model".format(epoch+1)
    torch.save(lstm, model_path)
    print("saved model: ", model_path)
writer.close()
# Out:
# epoch:1, step:50, loss:3.4944095611572266
# f1 [0.47222222 0.02840909]
# Epoch 0/500, P 0.5123, R 0.5008, F 0.2503, AUC 0.5345
# saved model:  ./model/lstm_1.model
# epoch:2, step:50, loss:3.482086658477783
# f1 [0.47113885 0.05571031]
# Epoch 1/500, P 0.5125, R 0.5016, F 0.2634, AUC 0.5528
# saved model:  ./model/lstm_2.model
# epoch:3, step:50, loss:3.475788116455078
# f1 [0.46885246 0.16923077]
# Epoch 2/500, P 0.5238, R 0.5091, F 0.3190, AUC 0.5708
# saved model:  ./model/lstm_3.model
# epoch:4, step:50, loss:3.468914747238159
# f1 [0.48114901 0.3476298 ]
# Epoch 3/500, P 0.5595, R 0.5439, F 0.4144, AUC 0.5852
# saved model:  ./model/lstm_4.model
# epoch:5, step:50, loss:3.4595234394073486
# f1 [0.48275862 0.49704142]
# Epoch 4/500, P 0.5649, R 0.5665, F 0.4899, AUC 0.5990
# saved model:  ./model/lstm_5.model
# epoch:6, step:50, loss:3.4496407508850098
# f1 [0.47727273 0.58928571]
# Epoch 5/500, P 0.5679, R 0.5778, F 0.5333, AUC 0.6122
# saved model:  ./model/lstm_6.model
# epoch:7, step:50, loss:3.4424641132354736
# f1 [0.45360825 0.65359477]
# Epoch 6/500, P 0.5634, R 0.5737, F 0.5536, AUC 0.6250
# saved model:  ./model/lstm_7.model
# epoch:8, step:50, loss:3.43455171585083
# f1 [0.44956772 0.70750383]
# Epoch 7/500, P 0.5781, R 0.5864, F 0.5785, AUC 0.6381
# saved model:  ./model/lstm_8.model
# epoch:9, step:50, loss:3.427818775177002
# f1 [0.44516129 0.75072464]
# Epoch 8/500, P 0.5979, R 0.5979, F 0.5979, AUC 0.6487
# saved model:  ./model/lstm_9.model
# epoch:10, step:50, loss:3.416818618774414
# f1 [0.45       0.78611111]
# Epoch 9/500, P 0.6293, R 0.6134, F 0.6181, AUC 0.6609
# saved model:  ./model/lstm_10.model
# epoch:11, step:50, loss:3.4105803966522217
# f1 [0.43445693 0.79399727]
# Epoch 10/500, P 0.6339, R 0.6088, F 0.6142, AUC 0.6744
# saved model:  ./model/lstm_11.model
# epoch:12, step:50, loss:3.399583101272583
# f1 [0.4291498 0.812749 ]
# Epoch 11/500, P 0.6630, R 0.6144, F 0.6209, AUC 0.6869
# saved model:  ./model/lstm_12.model
# epoch:13, step:50, loss:3.392670154571533
# f1 [0.42194093 0.82044561]
# Epoch 12/500, P 0.6793, R 0.6149, F 0.6212, AUC 0.6991
# saved model:  ./model/lstm_13.model
# epoch:14, step:50, loss:3.3813629150390625
# f1 [0.41558442 0.82444733]
# Epoch 13/500, P 0.6896, R 0.6143, F 0.6200, AUC 0.7120
# saved model:  ./model/lstm_14.model
# epoch:15, step:50, loss:3.3732450008392334
# f1 [0.42152466 0.83397683]
# Epoch 14/500, P 0.7206, R 0.6212, F 0.6278, AUC 0.7238
# saved model:  ./model/lstm_15.model
# epoch:16, step:50, loss:3.359020233154297
# f1 [0.42201835 0.83887468]
# Epoch 15/500, P 0.7404, R 0.6237, F 0.6304, AUC 0.7362
# saved model:  ./model/lstm_16.model
# epoch:17, step:50, loss:3.3491780757904053
# f1 [0.41860465 0.84076433]
# Epoch 16/500, P 0.7500, R 0.6234, F 0.6297, AUC 0.7471
# saved model:  ./model/lstm_17.model
# epoch:18, step:50, loss:3.330799102783203
# f1 [0.42592593 0.84183673]
# Epoch 17/500, P 0.7529, R 0.6266, F 0.6339, AUC 0.7591
# saved model:  ./model/lstm_18.model
# epoch:19, step:50, loss:3.322420835494995
# f1 [0.42790698 0.8433121 ]
# Epoch 18/500, P 0.7595, R 0.6281, F 0.6356, AUC 0.7717
# saved model:  ./model/lstm_19.model
# epoch:20, step:50, loss:3.3034799098968506
# f1 [0.43518519 0.84438776]
# Epoch 19/500, P 0.7622, R 0.6313, F 0.6398, AUC 0.7833
# saved model:  ./model/lstm_20.model
# epoch:21, step:50, loss:3.281599760055542
# f1 [0.44036697 0.84398977]
# Epoch 20/500, P 0.7585, R 0.6331, F 0.6422, AUC 0.7919
# saved model:  ./model/lstm_21.model
# epoch:22, step:50, loss:3.268195867538452
# f1 [0.44343891 0.84210526]
# Epoch 21/500, P 0.7491, R 0.6334, F 0.6428, AUC 0.8012
# saved model:  ./model/lstm_22.model
# epoch:23, step:50, loss:3.245508909225464
# f1 [0.46017699 0.84237726]
# Epoch 22/500, P 0.7462, R 0.6402, F 0.6513, AUC 0.8105
# saved model:  ./model/lstm_23.model
# epoch:24, step:50, loss:3.2251148223876953
# f1 [0.4845815  0.84864166]
# Epoch 23/500, P 0.7651, R 0.6528, F 0.6666, AUC 0.8185
# saved model:  ./model/lstm_24.model
# epoch:25, step:50, loss:3.2037277221679688
# f1 [0.49785408 0.84745763]
# Epoch 24/500, P 0.7569, R 0.6581, F 0.6727, AUC 0.8251
# saved model:  ./model/lstm_25.model
# epoch:26, step:50, loss:3.177837610244751
# f1 [0.53333333 0.85263158]
# Epoch 25/500, P 0.7668, R 0.6760, F 0.6930, AUC 0.8309
# saved model:  ./model/lstm_26.model
# epoch:27, step:50, loss:3.144286870956421
# f1 [0.54693878 0.85298013]
# Epoch 26/500, P 0.7649, R 0.6828, F 0.7000, AUC 0.8365
# saved model:  ./model/lstm_27.model
# epoch:28, step:50, loss:3.102457284927368
# f1 [0.5498008  0.84913218]
# Epoch 27/500, P 0.7529, R 0.6835, F 0.6995, AUC 0.8416
# saved model:  ./model/lstm_28.model
# epoch:29, step:50, loss:3.0745131969451904
# f1 [0.5703125  0.85215054]
# Epoch 28/500, P 0.7586, R 0.6949, F 0.7112, AUC 0.8464
# saved model:  ./model/lstm_29.model
# epoch:30, step:50, loss:3.0210988521575928
# f1 [0.60150376 0.85558583]
# Epoch 29/500, P 0.7640, R 0.7131, F 0.7285, AUC 0.8513
# saved model:  ./model/lstm_30.model
# epoch:31, step:50, loss:2.974924087524414
# f1 [0.60805861 0.85281981]
# Epoch 30/500, P 0.7575, R 0.7170, F 0.7304, AUC 0.8550
# saved model:  ./model/lstm_31.model
# epoch:32, step:50, loss:2.9371705055236816
# f1 [0.65492958 0.86312849]
# Epoch 31/500, P 0.7769, R 0.7478, F 0.7590, AUC 0.8583
# saved model:  ./model/lstm_32.model
# epoch:33, step:50, loss:2.8811349868774414
# f1 [0.68918919 0.86931818]
# Epoch 32/500, P 0.7879, R 0.7725, F 0.7793, AUC 0.8614
# saved model:  ./model/lstm_33.model
# epoch:34, step:50, loss:2.8100006580352783
# f1 [0.69078947 0.86494253]
# Epoch 33/500, P 0.7811, R 0.7749, F 0.7779, AUC 0.8650
# saved model:  ./model/lstm_34.model
# epoch:35, step:50, loss:2.7622790336608887
# f1 [0.69736842 0.86781609]
# Epoch 34/500, P 0.7859, R 0.7796, F 0.7826, AUC 0.8676
# saved model:  ./model/lstm_35.model
# epoch:36, step:50, loss:2.7095999717712402
# f1 [0.69781931 0.85714286]
# Epoch 35/500, P 0.7730, R 0.7830, F 0.7775, AUC 0.8700
# saved model:  ./model/lstm_36.model
# epoch:37, step:50, loss:2.6705024242401123
# f1 [0.69781931 0.85714286]
# Epoch 36/500, P 0.7730, R 0.7830, F 0.7775, AUC 0.8711
# saved model:  ./model/lstm_37.model
# epoch:38, step:50, loss:2.600916624069214
# f1 [0.6969697  0.85074627]
# Epoch 37/500, P 0.7670, R 0.7840, F 0.7739, AUC 0.8727
# saved model:  ./model/lstm_38.model
# epoch:39, step:50, loss:2.568481922149658
# f1 [0.69461078 0.84684685]
# Epoch 38/500, P 0.7633, R 0.7829, F 0.7707, AUC 0.8729
# saved model:  ./model/lstm_39.model
# epoch:40, step:50, loss:2.5299081802368164
# f1 [0.69069069 0.84557721]
# Epoch 39/500, P 0.7609, R 0.7797, F 0.7681, AUC 0.8728
# saved model:  ./model/lstm_40.model
# epoch:41, step:50, loss:2.5035054683685303
# f1 [0.69436202 0.84464555]
# Epoch 40/500, P 0.7617, R 0.7832, F 0.7695, AUC 0.8738
# saved model:  ./model/lstm_41.model
# epoch:42, step:50, loss:2.4795150756835938
# f1 [0.68882175 0.84603886]
# Epoch 41/500, P 0.7606, R 0.7779, F 0.7674, AUC 0.8732
# saved model:  ./model/lstm_42.model
# epoch:43, step:50, loss:2.455864667892456
# f1 [0.69590643 0.84194529]
# Epoch 42/500, P 0.7607, R 0.7853, F 0.7689, AUC 0.8763
# saved model:  ./model/lstm_43.model
# epoch:44, step:50, loss:2.4593026638031006
# f1 [0.69822485 0.84592145]
# Epoch 43/500, P 0.7640, R 0.7864, F 0.7721, AUC 0.8764
# saved model:  ./model/lstm_44.model
# epoch:45, step:50, loss:2.432110548019409
# f1 [0.69794721 0.84370258]
# Epoch 44/500, P 0.7626, R 0.7868, F 0.7708, AUC 0.8778
# saved model:  ./model/lstm_45.model
# epoch:46, step:50, loss:2.42832350730896
# f1 [0.70588235 0.84848485]
# Epoch 45/500, P 0.7688, R 0.7929, F 0.7772, AUC 0.8793
# saved model:  ./model/lstm_46.model
# epoch:47, step:50, loss:2.4003663063049316
# f1 [0.71098266 0.8470948 ]
# Epoch 46/500, P 0.7702, R 0.7982, F 0.7790, AUC 0.8810
# saved model:  ./model/lstm_47.model
# epoch:48, step:50, loss:2.3998591899871826
# f1 [0.71304348 0.84885496]
# Epoch 47/500, P 0.7721, R 0.7997, F 0.7809, AUC 0.8822
# saved model:  ./model/lstm_48.model
# epoch:49, step:50, loss:2.389320135116577
# f1 [0.71345029 0.85106383]
# Epoch 48/500, P 0.7735, R 0.7993, F 0.7823, AUC 0.8829
# saved model:  ./model/lstm_49.model
# epoch:50, step:50, loss:2.331545114517212
# f1 [0.7183908  0.84969325]
# Epoch 49/500, P 0.7750, R 0.8047, F 0.7840, AUC 0.8851
# saved model:  ./model/lstm_50.model
# epoch:51, step:50, loss:2.32684326171875
# f1 [0.7204611  0.85145482]
# Epoch 50/500, P 0.7768, R 0.8061, F 0.7860, AUC 0.8864
# saved model:  ./model/lstm_51.model
# epoch:52, step:50, loss:2.3386707305908203
# f1 [0.72206304 0.85099846]
# Epoch 51/500, P 0.7774, R 0.8079, F 0.7865, AUC 0.8878
# saved model:  ./model/lstm_52.model
# epoch:53, step:50, loss:2.303621530532837
# f1 [0.7204611  0.85145482]
# Epoch 52/500, P 0.7768, R 0.8061, F 0.7860, AUC 0.8890
# saved model:  ./model/lstm_53.model
# epoch:54, step:50, loss:2.2782888412475586
# f1 [0.71794872 0.84745763]
# Epoch 53/500, P 0.7737, R 0.8050, F 0.7827, AUC 0.8902
# saved model:  ./model/lstm_54.model
# epoch:55, step:50, loss:2.310389518737793
# f1 [0.71428571 0.84615385]
# Epoch 54/500, P 0.7713, R 0.8018, F 0.7802, AUC 0.8911
# saved model:  ./model/lstm_55.model
# epoch:56, step:50, loss:2.2868239879608154
# f1 [0.71469741 0.84839204]
# Epoch 55/500, P 0.7726, R 0.8014, F 0.7815, AUC 0.8923
# saved model:  ./model/lstm_56.model
# epoch:57, step:50, loss:2.2584924697875977
# f1 [0.71676301 0.85015291]
# Epoch 56/500, P 0.7744, R 0.8029, F 0.7835, AUC 0.8934
# saved model:  ./model/lstm_57.model
# epoch:58, step:50, loss:2.2546164989471436
# f1 [0.72521246 0.85007728]
# Epoch 57/500, P 0.7785, R 0.8115, F 0.7876, AUC 0.8950
# saved model:  ./model/lstm_58.model
# epoch:59, step:50, loss:2.242117404937744
# f1 [0.72521246 0.85007728]
# Epoch 58/500, P 0.7785, R 0.8115, F 0.7876, AUC 0.8959
# saved model:  ./model/lstm_59.model
# epoch:60, step:50, loss:2.226858615875244
# f1 [0.72316384 0.84829721]
# Epoch 59/500, P 0.7768, R 0.8100, F 0.7857, AUC 0.8971
# saved model:  ./model/lstm_60.model
# epoch:61, step:50, loss:2.2430169582366943
# f1 [0.7277937  0.85407066]
# Epoch 60/500, P 0.7816, R 0.8126, F 0.7909, AUC 0.8979
# saved model:  ./model/lstm_61.model
# epoch:62, step:50, loss:2.241891622543335
# f1 [0.73623188 0.8610687 ]
# Epoch 61/500, P 0.7890, R 0.8184, F 0.7987, AUC 0.8989
# saved model:  ./model/lstm_62.model
# epoch:63, step:50, loss:2.2089316844940186
# f1 [0.73239437 0.85271318]
# Epoch 62/500, P 0.7833, R 0.8179, F 0.7926, AUC 0.9004
# saved model:  ./model/lstm_63.model
# epoch:64, step:50, loss:2.183753728866577
# f1 [0.73714286 0.85846154]
# Epoch 63/500, P 0.7881, R 0.8205, F 0.7978, AUC 0.9012
# saved model:  ./model/lstm_64.model
# epoch:65, step:50, loss:2.1814868450164795
# f1 [0.73863636 0.85802469]
# Epoch 64/500, P 0.7887, R 0.8223, F 0.7983, AUC 0.9025
# saved model:  ./model/lstm_65.model
# epoch:66, step:50, loss:2.1788346767425537
# f1 [0.74635569 0.86757991]
# Epoch 65/500, P 0.7972, R 0.8259, F 0.8070, AUC 0.9028
# saved model:  ./model/lstm_66.model
# epoch:67, step:50, loss:2.1827142238616943
# f1 [0.74074074 0.85978428]
# Epoch 66/500, P 0.7905, R 0.8237, F 0.8003, AUC 0.9046
# saved model:  ./model/lstm_67.model
# epoch:68, step:50, loss:2.2032039165496826
# f1 [0.74927954 0.86676876]
# Epoch 67/500, P 0.7980, R 0.8295, F 0.8080, AUC 0.9052
# saved model:  ./model/lstm_68.model
# epoch:69, step:50, loss:2.1685585975646973
# f1 [0.75581395 0.87195122]
# Epoch 68/500, P 0.8037, R 0.8338, F 0.8139, AUC 0.9056
# saved model:  ./model/lstm_69.model
# epoch:70, step:50, loss:2.1835520267486572
# f1 [0.75144509 0.86850153]
# Epoch 69/500, P 0.7999, R 0.8309, F 0.8100, AUC 0.9067
# saved model:  ./model/lstm_70.model
# epoch:71, step:50, loss:2.1348214149475098
# f1 [0.75438596 0.87234043]
# Epoch 70/500, P 0.8034, R 0.8321, F 0.8134, AUC 0.9070
# saved model:  ./model/lstm_71.model
# epoch:72, step:50, loss:2.1319031715393066
# f1 [0.75882353 0.87575758]
# Epoch 71/500, P 0.8074, R 0.8350, F 0.8173, AUC 0.9078
# saved model:  ./model/lstm_72.model
# epoch:73, step:50, loss:2.093668222427368
# f1 [0.75942029 0.87328244]
# Epoch 72/500, P 0.8060, R 0.8371, F 0.8164, AUC 0.9083
# saved model:  ./model/lstm_73.model
# epoch:74, step:50, loss:2.1349122524261475
# f1 [0.76246334 0.87708649]
# Epoch 73/500, P 0.8097, R 0.8382, F 0.8198, AUC 0.9090
# saved model:  ./model/lstm_74.model
# epoch:75, step:50, loss:2.137021541595459
# f1 [0.76331361 0.87915408]
# Epoch 74/500, P 0.8114, R 0.8379, F 0.8212, AUC 0.9098
# saved model:  ./model/lstm_75.model
# epoch:76, step:50, loss:2.117020845413208
# f1 [0.76557864 0.88084465]
# Epoch 75/500, P 0.8135, R 0.8393, F 0.8232, AUC 0.9105
# saved model:  ./model/lstm_76.model
# epoch:77, step:50, loss:2.1143243312835693
# f1 [0.76557864 0.88084465]
# Epoch 76/500, P 0.8135, R 0.8393, F 0.8232, AUC 0.9110
# saved model:  ./model/lstm_77.model
# epoch:78, step:50, loss:2.1162431240081787
# f1 [0.77286136 0.88350983]
# Epoch 77/500, P 0.8180, R 0.8458, F 0.8282, AUC 0.9114
# saved model:  ./model/lstm_78.model
# epoch:79, step:50, loss:2.118941307067871
# f1 [0.77286136 0.88350983]
# Epoch 78/500, P 0.8180, R 0.8458, F 0.8282, AUC 0.9120
# saved model:  ./model/lstm_79.model
# epoch:80, step:50, loss:2.0942986011505127
# f1 [0.76785714 0.88253012]
# Epoch 79/500, P 0.8156, R 0.8408, F 0.8252, AUC 0.9127
# saved model:  ./model/lstm_80.model
# epoch:81, step:50, loss:2.0882842540740967
# f1 [0.77014925 0.88421053]
# Epoch 80/500, P 0.8177, R 0.8422, F 0.8272, AUC 0.9136
# saved model:  ./model/lstm_81.model
# epoch:82, step:50, loss:2.079638719558716
# f1 [0.77514793 0.88519637]
# Epoch 81/500, P 0.8201, R 0.8472, F 0.8302, AUC 0.9138
# saved model:  ./model/lstm_82.model
# epoch:83, step:50, loss:2.075796604156494
# f1 [0.77151335 0.88386124]
# Epoch 82/500, P 0.8178, R 0.8440, F 0.8277, AUC 0.9141
# saved model:  ./model/lstm_83.model
# epoch:84, step:50, loss:2.051320791244507
# f1 [0.77380952 0.88554217]
# Epoch 83/500, P 0.8199, R 0.8454, F 0.8297, AUC 0.9147
# saved model:  ./model/lstm_84.model
# epoch:85, step:50, loss:2.057961940765381
# f1 [0.77151335 0.88386124]
# Epoch 84/500, P 0.8178, R 0.8440, F 0.8277, AUC 0.9149
# saved model:  ./model/lstm_85.model
# epoch:86, step:50, loss:2.072988510131836
# f1 [0.77380952 0.88554217]
# Epoch 85/500, P 0.8199, R 0.8454, F 0.8297, AUC 0.9152
# saved model:  ./model/lstm_86.model
# epoch:87, step:50, loss:2.0315020084381104
# f1 [0.77710843 0.88922156]
# Epoch 86/500, P 0.8242, R 0.8466, F 0.8332, AUC 0.9157
# saved model:  ./model/lstm_87.model
# epoch:88, step:50, loss:2.066770076751709
# f1 [0.78078078 0.89055472]
# Epoch 87/500, P 0.8263, R 0.8498, F 0.8357, AUC 0.9160
# saved model:  ./model/lstm_88.model
# epoch:89, step:50, loss:2.057859182357788
# f1 [0.77744807 0.88687783]
# Epoch 88/500, P 0.8222, R 0.8487, F 0.8322, AUC 0.9163
# saved model:  ./model/lstm_89.model
# epoch:90, step:50, loss:2.0528981685638428
# f1 [0.77744807 0.88687783]
# Epoch 89/500, P 0.8222, R 0.8487, F 0.8322, AUC 0.9164
# saved model:  ./model/lstm_90.model
# epoch:91, step:50, loss:1.991201400756836
# f1 [0.77945619 0.89088191]
# Epoch 90/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9166
# saved model:  ./model/lstm_91.model
# epoch:92, step:50, loss:2.026859998703003
# f1 [0.77477477 0.88755622]
# Epoch 91/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9167
# saved model:  ./model/lstm_92.model
# epoch:93, step:50, loss:2.0439860820770264
# f1 [0.77477477 0.88755622]
# Epoch 92/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9170
# saved model:  ./model/lstm_93.model
# epoch:94, step:50, loss:2.0110461711883545
# f1 [0.7761194  0.88721805]
# Epoch 93/500, P 0.8220, R 0.8469, F 0.8317, AUC 0.9170
# saved model:  ./model/lstm_94.model
# epoch:95, step:50, loss:2.0140750408172607
# f1 [0.77477477 0.88755622]
# Epoch 94/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9173
# saved model:  ./model/lstm_95.model
# epoch:96, step:50, loss:2.0325934886932373
# f1 [0.77477477 0.88755622]
# Epoch 95/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9177
# saved model:  ./model/lstm_96.model
# epoch:97, step:50, loss:2.009354591369629
# f1 [0.77514793 0.88519637]
# Epoch 96/500, P 0.8201, R 0.8472, F 0.8302, AUC 0.9178
# saved model:  ./model/lstm_97.model
# epoch:98, step:50, loss:2.0072951316833496
# f1 [0.77744807 0.88687783]
# Epoch 97/500, P 0.8222, R 0.8487, F 0.8322, AUC 0.9181
# saved model:  ./model/lstm_98.model
# epoch:99, step:50, loss:1.9841314554214478
# f1 [0.77844311 0.88888889]
# Epoch 98/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9182
# saved model:  ./model/lstm_99.model
# epoch:100, step:50, loss:2.0069005489349365
# f1 [0.77477477 0.88755622]
# Epoch 99/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9184
# saved model:  ./model/lstm_100.model
# epoch:101, step:50, loss:1.93379807472229
# f1 [0.77844311 0.88888889]
# Epoch 100/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9186
# saved model:  ./model/lstm_101.model
# epoch:102, step:50, loss:1.9623316526412964
# f1 [0.77477477 0.88755622]
# Epoch 101/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9187
# saved model:  ./model/lstm_102.model
# epoch:103, step:50, loss:1.9930590391159058
# f1 [0.77844311 0.88888889]
# Epoch 102/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9188
# saved model:  ./model/lstm_103.model
# epoch:104, step:50, loss:1.9844112396240234
# f1 [0.77844311 0.88888889]
# Epoch 103/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9190
# saved model:  ./model/lstm_104.model
# epoch:105, step:50, loss:1.9648348093032837
# f1 [0.7797619  0.88855422]
# Epoch 104/500, P 0.8243, R 0.8501, F 0.8342, AUC 0.9190
# saved model:  ./model/lstm_105.model
# epoch:106, step:50, loss:1.9263638257980347
# f1 [0.77477477 0.88755622]
# Epoch 105/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9191
# saved model:  ./model/lstm_106.model
# epoch:107, step:50, loss:1.9812520742416382
# f1 [0.77945619 0.89088191]
# Epoch 106/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9192
# saved model:  ./model/lstm_107.model
# epoch:108, step:50, loss:1.9543412923812866
# f1 [0.77945619 0.89088191]
# Epoch 107/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9196
# saved model:  ./model/lstm_108.model
# epoch:109, step:50, loss:1.9527629613876343
# f1 [0.7797619  0.88855422]
# Epoch 108/500, P 0.8243, R 0.8501, F 0.8342, AUC 0.9197
# saved model:  ./model/lstm_109.model
# epoch:110, step:50, loss:1.9765571355819702
# f1 [0.77710843 0.88922156]
# Epoch 109/500, P 0.8242, R 0.8466, F 0.8332, AUC 0.9198
# saved model:  ./model/lstm_110.model
# epoch:111, step:50, loss:1.9355791807174683
# f1 [0.77710843 0.88922156]
# Epoch 110/500, P 0.8242, R 0.8466, F 0.8332, AUC 0.9199
# saved model:  ./model/lstm_111.model
# epoch:112, step:50, loss:1.9430582523345947
# f1 [0.77477477 0.88755622]
# Epoch 111/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9199
# saved model:  ./model/lstm_112.model
# epoch:113, step:50, loss:1.900763750076294
# f1 [0.77844311 0.88888889]
# Epoch 112/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9202
# saved model:  ./model/lstm_113.model
# epoch:114, step:50, loss:1.9395391941070557
# f1 [0.77844311 0.88888889]
# Epoch 113/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9205
# saved model:  ./model/lstm_114.model
# epoch:115, step:50, loss:1.9583109617233276
# f1 [0.77945619 0.89088191]
# Epoch 114/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9200
# saved model:  ./model/lstm_115.model
# epoch:116, step:50, loss:1.9452491998672485
# f1 [0.77945619 0.89088191]
# Epoch 115/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9203
# saved model:  ./model/lstm_116.model
# epoch:117, step:50, loss:1.9148590564727783
# f1 [0.78208955 0.89022556]
# Epoch 116/500, P 0.8264, R 0.8516, F 0.8362, AUC 0.9210
# saved model:  ./model/lstm_117.model
# epoch:118, step:50, loss:1.9429110288619995
# f1 [0.7791411  0.89317507]
# Epoch 117/500, P 0.8288, R 0.8459, F 0.8362, AUC 0.9203
# saved model:  ./model/lstm_118.model
# epoch:119, step:50, loss:1.908553123474121
# f1 [0.78208955 0.89022556]
# Epoch 118/500, P 0.8264, R 0.8516, F 0.8362, AUC 0.9211
# saved model:  ./model/lstm_119.model
# epoch:120, step:50, loss:1.892669677734375
# f1 [0.77477477 0.88755622]
# Epoch 119/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9213
# saved model:  ./model/lstm_120.model
# epoch:121, step:50, loss:1.9071985483169556
# f1 [0.77477477 0.88755622]
# Epoch 120/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9210
# saved model:  ./model/lstm_121.model
# epoch:122, step:50, loss:1.8831933736801147
# f1 [0.7797619  0.88855422]
# Epoch 121/500, P 0.8243, R 0.8501, F 0.8342, AUC 0.9213
# saved model:  ./model/lstm_122.model
# epoch:123, step:50, loss:1.913242220878601
# f1 [0.77844311 0.88888889]
# Epoch 122/500, P 0.8242, R 0.8483, F 0.8337, AUC 0.9213
# saved model:  ./model/lstm_123.model
# epoch:124, step:50, loss:1.8817249536514282
# f1 [0.78208955 0.89022556]
# Epoch 123/500, P 0.8264, R 0.8516, F 0.8362, AUC 0.9214
# saved model:  ./model/lstm_124.model
# epoch:125, step:50, loss:1.9131020307540894
# f1 [0.77945619 0.89088191]
# Epoch 124/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9213
# saved model:  ./model/lstm_125.model
# epoch:126, step:50, loss:1.844018816947937
# f1 [0.78313253 0.89221557]
# Epoch 125/500, P 0.8285, R 0.8512, F 0.8377, AUC 0.9215
# saved model:  ./model/lstm_126.model
# epoch:127, step:50, loss:1.8737848997116089
# f1 [0.78078078 0.89055472]
# Epoch 126/500, P 0.8263, R 0.8498, F 0.8357, AUC 0.9218
# saved model:  ./model/lstm_127.model
# epoch:128, step:50, loss:1.855650544166565
# f1 [0.7804878  0.89285714]
# Epoch 127/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9217
# saved model:  ./model/lstm_128.model
# epoch:129, step:50, loss:1.873534083366394
# f1 [0.7804878  0.89285714]
# Epoch 128/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9218
# saved model:  ./model/lstm_129.model
# epoch:130, step:50, loss:1.8525053262710571
# f1 [0.77945619 0.89088191]
# Epoch 129/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9217
# saved model:  ./model/lstm_130.model
# epoch:131, step:50, loss:1.8868471384048462
# f1 [0.78181818 0.89253731]
# Epoch 130/500, P 0.8286, R 0.8495, F 0.8372, AUC 0.9219
# saved model:  ./model/lstm_131.model
# epoch:132, step:50, loss:1.8514641523361206
# f1 [0.77945619 0.89088191]
# Epoch 131/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9220
# saved model:  ./model/lstm_132.model
# epoch:133, step:50, loss:1.824532151222229
# f1 [0.77710843 0.88922156]
# Epoch 132/500, P 0.8242, R 0.8466, F 0.8332, AUC 0.9221
# saved model:  ./model/lstm_133.model
# epoch:134, step:50, loss:1.8301562070846558
# f1 [0.78078078 0.89055472]
# Epoch 133/500, P 0.8263, R 0.8498, F 0.8357, AUC 0.9224
# saved model:  ./model/lstm_134.model
# epoch:135, step:50, loss:1.8438074588775635
# f1 [0.78181818 0.89253731]
# Epoch 134/500, P 0.8286, R 0.8495, F 0.8372, AUC 0.9224
# saved model:  ./model/lstm_135.model
# epoch:136, step:50, loss:1.781240701675415
# f1 [0.78208955 0.89022556]
# Epoch 135/500, P 0.8264, R 0.8516, F 0.8362, AUC 0.9223
# saved model:  ./model/lstm_136.model
# epoch:137, step:50, loss:1.8478338718414307
# f1 [0.77477477 0.88755622]
# Epoch 136/500, P 0.8220, R 0.8451, F 0.8312, AUC 0.9226
# saved model:  ./model/lstm_137.model
# epoch:138, step:50, loss:1.8376636505126953
# f1 [0.78181818 0.89253731]
# Epoch 137/500, P 0.8286, R 0.8495, F 0.8372, AUC 0.9227
# saved model:  ./model/lstm_138.model
# epoch:139, step:50, loss:1.8136974573135376
# f1 [0.78181818 0.89253731]
# Epoch 138/500, P 0.8286, R 0.8495, F 0.8372, AUC 0.9227
# saved model:  ./model/lstm_139.model
# epoch:140, step:50, loss:1.831498384475708
# f1 [0.78419453 0.89418778]
# Epoch 139/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9224
# saved model:  ./model/lstm_140.model
# epoch:141, step:50, loss:1.82704758644104
# f1 [0.78419453 0.89418778]
# Epoch 140/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9227
# saved model:  ./model/lstm_141.model
# epoch:142, step:50, loss:1.8080965280532837
# f1 [0.78181818 0.89253731]
# Epoch 141/500, P 0.8286, R 0.8495, F 0.8372, AUC 0.9227
# saved model:  ./model/lstm_142.model
# epoch:143, step:50, loss:1.798914909362793
# f1 [0.7804878  0.89285714]
# Epoch 142/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9224
# saved model:  ./model/lstm_143.model
# epoch:144, step:50, loss:1.8132600784301758
# f1 [0.78549849 0.89387145]
# Epoch 143/500, P 0.8307, R 0.8527, F 0.8397, AUC 0.9229
# saved model:  ./model/lstm_144.model
# epoch:145, step:50, loss:1.820072054862976
# f1 [0.78313253 0.89221557]
# Epoch 144/500, P 0.8285, R 0.8512, F 0.8377, AUC 0.9230
# saved model:  ./model/lstm_145.model
# epoch:146, step:50, loss:1.7919502258300781
# f1 [0.78549849 0.89387145]
# Epoch 145/500, P 0.8307, R 0.8527, F 0.8397, AUC 0.9231
# saved model:  ./model/lstm_146.model
# epoch:147, step:50, loss:1.7884457111358643
# f1 [0.78419453 0.89418778]
# Epoch 146/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9231
# saved model:  ./model/lstm_147.model
# epoch:148, step:50, loss:1.8276811838150024
# f1 [0.78419453 0.89418778]
# Epoch 147/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9231
# saved model:  ./model/lstm_148.model
# epoch:149, step:50, loss:1.7640886306762695
# f1 [0.78419453 0.89418778]
# Epoch 148/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9231
# saved model:  ./model/lstm_149.model
# epoch:150, step:50, loss:1.7954124212265015
# f1 [0.78419453 0.89418778]
# Epoch 149/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9233
# saved model:  ./model/lstm_150.model
# epoch:151, step:50, loss:1.7843023538589478
# f1 [0.78658537 0.89583333]
# Epoch 150/500, P 0.8331, R 0.8524, F 0.8412, AUC 0.9233
# saved model:  ./model/lstm_151.model
# epoch:152, step:50, loss:1.7883471250534058
# f1 [0.78419453 0.89418778]
# Epoch 151/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9234
# saved model:  ./model/lstm_152.model
# epoch:153, step:50, loss:1.7548950910568237
# f1 [0.78419453 0.89418778]
# Epoch 152/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9234
# saved model:  ./model/lstm_153.model
# epoch:154, step:50, loss:1.7736873626708984
# f1 [0.78419453 0.89418778]
# Epoch 153/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9235
# saved model:  ./model/lstm_154.model
# epoch:155, step:50, loss:1.747292399406433
# f1 [0.77945619 0.89088191]
# Epoch 154/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9236
# saved model:  ./model/lstm_155.model
# epoch:156, step:50, loss:1.7438766956329346
# f1 [0.78419453 0.89418778]
# Epoch 155/500, P 0.8308, R 0.8509, F 0.8392, AUC 0.9235
# saved model:  ./model/lstm_156.model
# epoch:157, step:50, loss:1.7276285886764526
# f1 [0.7804878  0.89285714]
# Epoch 156/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9235
# saved model:  ./model/lstm_157.model
# epoch:158, step:50, loss:1.7480156421661377
# f1 [0.7804878  0.89285714]
# Epoch 157/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9235
# saved model:  ./model/lstm_158.model
# epoch:159, step:50, loss:1.7758750915527344
# f1 [0.7804878  0.89285714]
# Epoch 158/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9235
# saved model:  ./model/lstm_159.model
# epoch:160, step:50, loss:1.7325111627578735
# f1 [0.7804878  0.89285714]
# Epoch 159/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9237
# saved model:  ./model/lstm_160.model
# epoch:161, step:50, loss:1.7542799711227417
# f1 [0.7804878  0.89285714]
# Epoch 160/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9235
# saved model:  ./model/lstm_161.model
# epoch:162, step:50, loss:1.7215973138809204
# f1 [0.7804878  0.89285714]
# Epoch 161/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9237
# saved model:  ./model/lstm_162.model
# epoch:163, step:50, loss:1.7132854461669922
# f1 [0.7804878  0.89285714]
# Epoch 162/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9239
# saved model:  ./model/lstm_163.model
# epoch:164, step:50, loss:1.7460412979125977
# f1 [0.7781155  0.89120715]
# Epoch 163/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9240
# saved model:  ./model/lstm_164.model
# epoch:165, step:50, loss:1.7130793333053589
# f1 [0.7804878  0.89285714]
# Epoch 164/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9237
# saved model:  ./model/lstm_165.model
# epoch:166, step:50, loss:1.7497094869613647
# f1 [0.78527607 0.89614243]
# Epoch 165/500, P 0.8332, R 0.8506, F 0.8407, AUC 0.9236
# saved model:  ./model/lstm_166.model
# epoch:167, step:50, loss:1.7408069372177124
# f1 [0.7804878  0.89285714]
# Epoch 166/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9237
# saved model:  ./model/lstm_167.model
# epoch:168, step:50, loss:1.7104942798614502
# f1 [0.7781155  0.89120715]
# Epoch 167/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9239
# saved model:  ./model/lstm_168.model
# epoch:169, step:50, loss:1.7064857482910156
# f1 [0.78395062 0.8964497 ]
# Epoch 168/500, P 0.8334, R 0.8488, F 0.8402, AUC 0.9237
# saved model:  ./model/lstm_169.model
# epoch:170, step:50, loss:1.7258366346359253
# f1 [0.7734139  0.88789238]
# Epoch 169/500, P 0.8220, R 0.8433, F 0.8307, AUC 0.9239
# saved model:  ./model/lstm_170.model
# epoch:171, step:50, loss:1.7137397527694702
# f1 [0.77575758 0.88955224]
# Epoch 170/500, P 0.8242, R 0.8448, F 0.8327, AUC 0.9237
# saved model:  ./model/lstm_171.model
# epoch:172, step:50, loss:1.6759414672851562
# f1 [0.7781155  0.89120715]
# Epoch 171/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9235
# saved model:  ./model/lstm_172.model
# epoch:173, step:50, loss:1.6453802585601807
# f1 [0.7781155  0.89120715]
# Epoch 172/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9236
# saved model:  ./model/lstm_173.model
# epoch:174, step:50, loss:1.7066599130630493
# f1 [0.7781155  0.89120715]
# Epoch 173/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9236
# saved model:  ./model/lstm_174.model
# epoch:175, step:50, loss:1.7046221494674683
# f1 [0.7791411  0.89317507]
# Epoch 174/500, P 0.8288, R 0.8459, F 0.8362, AUC 0.9237
# saved model:  ./model/lstm_175.model
# epoch:176, step:50, loss:1.7040208578109741
# f1 [0.77945619 0.89088191]
# Epoch 175/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9241
# saved model:  ./model/lstm_176.model
# epoch:177, step:50, loss:1.7076681852340698
# f1 [0.77945619 0.89088191]
# Epoch 176/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9240
# saved model:  ./model/lstm_177.model
# epoch:178, step:50, loss:1.7386465072631836
# f1 [0.7804878  0.89285714]
# Epoch 177/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9240
# saved model:  ./model/lstm_178.model
# epoch:179, step:50, loss:1.6688913106918335
# f1 [0.78395062 0.8964497 ]
# Epoch 178/500, P 0.8334, R 0.8488, F 0.8402, AUC 0.9241
# saved model:  ./model/lstm_179.model
# epoch:180, step:50, loss:1.6479285955429077
# f1 [0.77675841 0.89153046]
# Epoch 179/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9240
# saved model:  ./model/lstm_180.model
# epoch:181, step:50, loss:1.6674925088882446
# f1 [0.77945619 0.89088191]
# Epoch 180/500, P 0.8264, R 0.8480, F 0.8352, AUC 0.9242
# saved model:  ./model/lstm_181.model
# epoch:182, step:50, loss:1.6737278699874878
# f1 [0.77675841 0.89153046]
# Epoch 181/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9242
# saved model:  ./model/lstm_182.model
# epoch:183, step:50, loss:1.646349310874939
# f1 [0.7781155  0.89120715]
# Epoch 182/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9240
# saved model:  ./model/lstm_183.model
# epoch:184, step:50, loss:1.6830580234527588
# f1 [0.77675841 0.89153046]
# Epoch 183/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9242
# saved model:  ./model/lstm_184.model
# epoch:185, step:50, loss:1.631861925125122
# f1 [0.78153846 0.89481481]
# Epoch 184/500, P 0.8311, R 0.8474, F 0.8382, AUC 0.9241
# saved model:  ./model/lstm_185.model
# epoch:186, step:50, loss:1.6347038745880127
# f1 [0.78153846 0.89481481]
# Epoch 185/500, P 0.8311, R 0.8474, F 0.8382, AUC 0.9243
# saved model:  ./model/lstm_186.model
# epoch:187, step:50, loss:1.6478999853134155
# f1 [0.7781155  0.89120715]
# Epoch 186/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9242
# saved model:  ./model/lstm_187.model
# epoch:188, step:50, loss:1.678044319152832
# f1 [0.77777778 0.89349112]
# Epoch 187/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9241
# saved model:  ./model/lstm_188.model
# epoch:189, step:50, loss:1.6539191007614136
# f1 [0.77777778 0.89349112]
# Epoch 188/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9242
# saved model:  ./model/lstm_189.model
# epoch:190, step:50, loss:1.6585224866867065
# f1 [0.7781155  0.89120715]
# Epoch 189/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9242
# saved model:  ./model/lstm_190.model
# epoch:191, step:50, loss:1.6449066400527954
# f1 [0.77777778 0.89349112]
# Epoch 190/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9242
# saved model:  ./model/lstm_191.model
# epoch:192, step:50, loss:1.6475162506103516
# f1 [0.78287462 0.89450223]
# Epoch 191/500, P 0.8309, R 0.8491, F 0.8387, AUC 0.9243
# saved model:  ./model/lstm_192.model
# epoch:193, step:50, loss:1.5943876504898071
# f1 [0.77777778 0.89349112]
# Epoch 192/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9241
# saved model:  ./model/lstm_193.model
# epoch:194, step:50, loss:1.6408127546310425
# f1 [0.77777778 0.89349112]
# Epoch 193/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9243
# saved model:  ./model/lstm_194.model
# epoch:195, step:50, loss:1.615692138671875
# f1 [0.77399381 0.89217134]
# Epoch 194/500, P 0.8268, R 0.8409, F 0.8331, AUC 0.9242
# saved model:  ./model/lstm_195.model
# epoch:196, step:50, loss:1.6494667530059814
# f1 [0.7791411  0.89317507]
# Epoch 195/500, P 0.8288, R 0.8459, F 0.8362, AUC 0.9241
# saved model:  ./model/lstm_196.model
# epoch:197, step:50, loss:1.6008294820785522
# f1 [0.77399381 0.89217134]
# Epoch 196/500, P 0.8268, R 0.8409, F 0.8331, AUC 0.9241
# saved model:  ./model/lstm_197.model
# epoch:198, step:50, loss:1.6121944189071655
# f1 [0.7791411  0.89317507]
# Epoch 197/500, P 0.8288, R 0.8459, F 0.8362, AUC 0.9242
# saved model:  ./model/lstm_198.model
# epoch:199, step:50, loss:1.6325052976608276
# f1 [0.77777778 0.89349112]
# Epoch 198/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9240
# saved model:  ./model/lstm_199.model
# epoch:200, step:50, loss:1.6009724140167236
# f1 [0.77675841 0.89153046]
# Epoch 199/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9241
# saved model:  ./model/lstm_200.model
# epoch:201, step:50, loss:1.5974656343460083
# f1 [0.77399381 0.89217134]
# Epoch 200/500, P 0.8268, R 0.8409, F 0.8331, AUC 0.9240
# saved model:  ./model/lstm_201.model
# epoch:202, step:50, loss:1.6037832498550415
# f1 [0.77399381 0.89217134]
# Epoch 201/500, P 0.8268, R 0.8409, F 0.8331, AUC 0.9240
# saved model:  ./model/lstm_202.model
# epoch:203, step:50, loss:1.6360117197036743
# f1 [0.7804878  0.89285714]
# Epoch 202/500, P 0.8287, R 0.8477, F 0.8367, AUC 0.9245
# saved model:  ./model/lstm_203.model
# epoch:204, step:50, loss:1.6127113103866577
# f1 [0.77639752 0.89380531]
# Epoch 203/500, P 0.8292, R 0.8424, F 0.8351, AUC 0.9240
# saved model:  ./model/lstm_204.model
# epoch:205, step:50, loss:1.6188255548477173
# f1 [0.77538462 0.89185185]
# Epoch 204/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9241
# saved model:  ./model/lstm_205.model
# epoch:206, step:50, loss:1.6073315143585205
# f1 [0.77675841 0.89153046]
# Epoch 205/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9242
# saved model:  ./model/lstm_206.model
# epoch:207, step:50, loss:1.6281852722167969
# f1 [0.7781155  0.89120715]
# Epoch 206/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9244
# saved model:  ./model/lstm_207.model
# epoch:208, step:50, loss:1.5773006677627563
# f1 [0.78018576 0.89512555]
# Epoch 207/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9238
# saved model:  ./model/lstm_208.model
# epoch:209, step:50, loss:1.5948797464370728
# f1 [0.77538462 0.89185185]
# Epoch 208/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9240
# saved model:  ./model/lstm_209.model
# epoch:210, step:50, loss:1.6030998229980469
# f1 [0.77538462 0.89185185]
# Epoch 209/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9242
# saved model:  ./model/lstm_210.model
# epoch:211, step:50, loss:1.5932397842407227
# f1 [0.7781155  0.89120715]
# Epoch 210/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9239
# saved model:  ./model/lstm_211.model
# epoch:212, step:50, loss:1.5714375972747803
# f1 [0.77300613 0.89020772]
# Epoch 211/500, P 0.8243, R 0.8412, F 0.8316, AUC 0.9240
# saved model:  ./model/lstm_212.model
# epoch:213, step:50, loss:1.5504577159881592
# f1 [0.77777778 0.89349112]
# Epoch 212/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9239
# saved model:  ./model/lstm_213.model
# epoch:214, step:50, loss:1.5849050283432007
# f1 [0.77675841 0.89153046]
# Epoch 213/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9241
# saved model:  ./model/lstm_214.model
# epoch:215, step:50, loss:1.5684661865234375
# f1 [0.77300613 0.89020772]
# Epoch 214/500, P 0.8243, R 0.8412, F 0.8316, AUC 0.9238
# saved model:  ./model/lstm_215.model
# epoch:216, step:50, loss:1.5829010009765625
# f1 [0.7781155  0.89120715]
# Epoch 215/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9241
# saved model:  ./model/lstm_216.model
# epoch:217, step:50, loss:1.5485097169876099
# f1 [0.77538462 0.89185185]
# Epoch 216/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9238
# saved model:  ./model/lstm_217.model
# epoch:218, step:50, loss:1.5576297044754028
# f1 [0.77675841 0.89153046]
# Epoch 217/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9240
# saved model:  ./model/lstm_218.model
# epoch:219, step:50, loss:1.5314182043075562
# f1 [0.77300613 0.89020772]
# Epoch 218/500, P 0.8243, R 0.8412, F 0.8316, AUC 0.9239
# saved model:  ./model/lstm_219.model
# epoch:220, step:50, loss:1.5320780277252197
# f1 [0.77399381 0.89217134]
# Epoch 219/500, P 0.8268, R 0.8409, F 0.8331, AUC 0.9240
# saved model:  ./model/lstm_220.model
# epoch:221, step:50, loss:1.5348858833312988
# f1 [0.7781155  0.89120715]
# Epoch 220/500, P 0.8264, R 0.8462, F 0.8347, AUC 0.9240
# saved model:  ./model/lstm_221.model
# epoch:222, step:50, loss:1.534224033355713
# f1 [0.77300613 0.89020772]
# Epoch 221/500, P 0.8243, R 0.8412, F 0.8316, AUC 0.9241
# saved model:  ./model/lstm_222.model
# epoch:223, step:50, loss:1.5198296308517456
# f1 [0.77675841 0.89153046]
# Epoch 222/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9241
# saved model:  ./model/lstm_223.model
# epoch:224, step:50, loss:1.5428998470306396
# f1 [0.77538462 0.89185185]
# Epoch 223/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9241
# saved model:  ./model/lstm_224.model
# epoch:225, step:50, loss:1.5269664525985718
# f1 [0.77160494 0.89053254]
# Epoch 224/500, P 0.8245, R 0.8395, F 0.8311, AUC 0.9243
# saved model:  ./model/lstm_225.model
# epoch:226, step:50, loss:1.5121679306030273
# f1 [0.77439024 0.88988095]
# Epoch 225/500, P 0.8242, R 0.8430, F 0.8321, AUC 0.9245
# saved model:  ./model/lstm_226.model
# epoch:227, step:50, loss:1.523825764656067
# f1 [0.77160494 0.89053254]
# Epoch 226/500, P 0.8245, R 0.8395, F 0.8311, AUC 0.9242
# saved model:  ./model/lstm_227.model
# epoch:228, step:50, loss:1.5233629941940308
# f1 [0.77160494 0.89053254]
# Epoch 227/500, P 0.8245, R 0.8395, F 0.8311, AUC 0.9244
# saved model:  ./model/lstm_228.model
# epoch:229, step:50, loss:1.5243115425109863
# f1 [0.77538462 0.89185185]
# Epoch 228/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9243
# saved model:  ./model/lstm_229.model
# epoch:230, step:50, loss:1.5330252647399902
# f1 [0.77439024 0.88988095]
# Epoch 229/500, P 0.8242, R 0.8430, F 0.8321, AUC 0.9242
# saved model:  ./model/lstm_230.model
# epoch:231, step:50, loss:1.5313736200332642
# f1 [0.77538462 0.89185185]
# Epoch 230/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9242
# saved model:  ./model/lstm_231.model
# epoch:232, step:50, loss:1.4907437562942505
# f1 [0.77987421 0.8973607 ]
# Epoch 231/500, P 0.8344, R 0.8435, F 0.8386, AUC 0.9242
# saved model:  ./model/lstm_232.model
# epoch:233, step:50, loss:1.4681586027145386
# f1 [0.77160494 0.89053254]
# Epoch 232/500, P 0.8245, R 0.8395, F 0.8311, AUC 0.9237
# saved model:  ./model/lstm_233.model
# epoch:234, step:50, loss:1.5322445631027222
# f1 [0.77439024 0.88988095]
# Epoch 233/500, P 0.8242, R 0.8430, F 0.8321, AUC 0.9240
# saved model:  ./model/lstm_234.model
# epoch:235, step:50, loss:1.5091180801391602
# f1 [0.77439024 0.88988095]
# Epoch 234/500, P 0.8242, R 0.8430, F 0.8321, AUC 0.9239
# saved model:  ./model/lstm_235.model
# epoch:236, step:50, loss:1.5010451078414917
# f1 [0.77300613 0.89020772]
# Epoch 235/500, P 0.8243, R 0.8412, F 0.8316, AUC 0.9239
# saved model:  ./model/lstm_236.model
# epoch:237, step:50, loss:1.4812034368515015
# f1 [0.7706422  0.88855869]
# Epoch 236/500, P 0.8221, R 0.8398, F 0.8296, AUC 0.9239
# saved model:  ./model/lstm_237.model
# epoch:238, step:50, loss:1.5027689933776855
# f1 [0.77399381 0.89217134]
# Epoch 237/500, P 0.8268, R 0.8409, F 0.8331, AUC 0.9238
# saved model:  ./model/lstm_238.model
# epoch:239, step:50, loss:1.4714535474777222
# f1 [0.7706422  0.88855869]
# Epoch 238/500, P 0.8221, R 0.8398, F 0.8296, AUC 0.9242
# saved model:  ./model/lstm_239.model
# epoch:240, step:50, loss:1.4816370010375977
# f1 [0.7706422  0.88855869]
# Epoch 239/500, P 0.8221, R 0.8398, F 0.8296, AUC 0.9237
# saved model:  ./model/lstm_240.model
# epoch:241, step:50, loss:1.4640849828720093
# f1 [0.7706422  0.88855869]
# Epoch 240/500, P 0.8221, R 0.8398, F 0.8296, AUC 0.9242
# saved model:  ./model/lstm_241.model
# epoch:242, step:50, loss:1.463822841644287
# f1 [0.78125    0.89705882]
# Epoch 241/500, P 0.8340, R 0.8453, F 0.8392, AUC 0.9238
# saved model:  ./model/lstm_242.model
# epoch:243, step:50, loss:1.4654897451400757
# f1 [0.7706422  0.88855869]
# Epoch 242/500, P 0.8221, R 0.8398, F 0.8296, AUC 0.9241
# saved model:  ./model/lstm_243.model
# epoch:244, step:50, loss:1.455200433731079
# f1 [0.77777778 0.89349112]
# Epoch 243/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9235
# saved model:  ./model/lstm_244.model
# epoch:245, step:50, loss:1.4559420347213745
# f1 [0.7826087  0.89675516]
# Epoch 244/500, P 0.8337, R 0.8470, F 0.8397, AUC 0.9236
# saved model:  ./model/lstm_245.model
# epoch:246, step:50, loss:1.492413878440857
# f1 [0.78018576 0.89512555]
# Epoch 245/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9235
# saved model:  ./model/lstm_246.model
# epoch:247, step:50, loss:1.4469026327133179
# f1 [0.77777778 0.89349112]
# Epoch 246/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9235
# saved model:  ./model/lstm_247.model
# epoch:248, step:50, loss:1.4526177644729614
# f1 [0.78018576 0.89512555]
# Epoch 247/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9235
# saved model:  ./model/lstm_248.model
# epoch:249, step:50, loss:1.4508774280548096
# f1 [0.77777778 0.89349112]
# Epoch 248/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9235
# saved model:  ./model/lstm_249.model
# epoch:250, step:50, loss:1.4474544525146484
# f1 [0.78018576 0.89512555]
# Epoch 249/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9234
# saved model:  ./model/lstm_250.model
# epoch:251, step:50, loss:1.425926685333252
# f1 [0.78018576 0.89512555]
# Epoch 250/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9233
# saved model:  ./model/lstm_251.model
# epoch:252, step:50, loss:1.4003633260726929
# f1 [0.78018576 0.89512555]
# Epoch 251/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9233
# saved model:  ./model/lstm_252.model
# epoch:253, step:50, loss:1.43839430809021
# f1 [0.7826087  0.89675516]
# Epoch 252/500, P 0.8337, R 0.8470, F 0.8397, AUC 0.9230
# saved model:  ./model/lstm_253.model
# epoch:254, step:50, loss:1.429824709892273
# f1 [0.77538462 0.89185185]
# Epoch 253/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9234
# saved model:  ./model/lstm_254.model
# epoch:255, step:50, loss:1.4538096189498901
# f1 [0.7826087  0.89675516]
# Epoch 254/500, P 0.8337, R 0.8470, F 0.8397, AUC 0.9230
# saved model:  ./model/lstm_255.model
# epoch:256, step:50, loss:1.413851022720337
# f1 [0.77777778 0.89349112]
# Epoch 255/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9234
# saved model:  ./model/lstm_256.model
# epoch:257, step:50, loss:1.3756211996078491
# f1 [0.75987842 0.88226528]
# Epoch 256/500, P 0.8132, R 0.8322, F 0.8211, AUC 0.9219
# saved model:  ./model/lstm_257.model
# epoch:258, step:50, loss:1.4048854112625122
# f1 [0.77987421 0.8973607 ]
# Epoch 257/500, P 0.8344, R 0.8435, F 0.8386, AUC 0.9231
# saved model:  ./model/lstm_258.model
# epoch:259, step:50, loss:1.3773622512817383
# f1 [0.78504673 0.89837997]
# Epoch 258/500, P 0.8361, R 0.8485, F 0.8417, AUC 0.9233
# saved model:  ./model/lstm_259.model
# epoch:260, step:50, loss:1.441909670829773
# f1 [0.79245283 0.90322581]
# Epoch 259/500, P 0.8435, R 0.8528, F 0.8478, AUC 0.9227
# saved model:  ./model/lstm_260.model
# epoch:261, step:50, loss:1.4251054525375366
# f1 [0.78018576 0.89512555]
# Epoch 260/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9233
# saved model:  ./model/lstm_261.model
# epoch:262, step:50, loss:1.3916349411010742
# f1 [0.7875 0.9   ]
# Epoch 261/500, P 0.8385, R 0.8499, F 0.8437, AUC 0.9228
# saved model:  ./model/lstm_262.model
# epoch:263, step:50, loss:1.403095006942749
# f1 [0.78018576 0.89512555]
# Epoch 262/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9229
# saved model:  ./model/lstm_263.model
# epoch:264, step:50, loss:1.4105061292648315
# f1 [0.77538462 0.89185185]
# Epoch 263/500, P 0.8266, R 0.8427, F 0.8336, AUC 0.9234
# saved model:  ./model/lstm_264.model
# epoch:265, step:50, loss:1.3946269750595093
# f1 [0.7875 0.9   ]
# Epoch 264/500, P 0.8385, R 0.8499, F 0.8437, AUC 0.9223
# saved model:  ./model/lstm_265.model
# epoch:266, step:50, loss:1.3929604291915894
# f1 [0.7875 0.9   ]
# Epoch 265/500, P 0.8385, R 0.8499, F 0.8437, AUC 0.9223
# saved model:  ./model/lstm_266.model
# epoch:267, step:50, loss:1.3819421529769897
# f1 [0.7826087  0.89675516]
# Epoch 266/500, P 0.8337, R 0.8470, F 0.8397, AUC 0.9226
# saved model:  ./model/lstm_267.model
# epoch:268, step:50, loss:1.392442226409912
# f1 [0.78018576 0.89512555]
# Epoch 267/500, P 0.8313, R 0.8456, F 0.8377, AUC 0.9227
# saved model:  ./model/lstm_268.model
# epoch:269, step:50, loss:1.3925668001174927
# f1 [0.77675841 0.89153046]
# Epoch 268/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9230
# saved model:  ./model/lstm_269.model
# epoch:270, step:50, loss:1.3884752988815308
# f1 [0.7826087  0.89675516]
# Epoch 269/500, P 0.8337, R 0.8470, F 0.8397, AUC 0.9226
# saved model:  ./model/lstm_270.model
# epoch:271, step:50, loss:1.3819140195846558
# f1 [0.7826087  0.89675516]
# Epoch 270/500, P 0.8337, R 0.8470, F 0.8397, AUC 0.9217
# saved model:  ./model/lstm_271.model
# epoch:272, step:50, loss:1.3739067316055298
# f1 [0.7791411  0.89317507]
# Epoch 271/500, P 0.8288, R 0.8459, F 0.8362, AUC 0.9225
# saved model:  ./model/lstm_272.model
# epoch:273, step:50, loss:1.3865269422531128
# f1 [0.78395062 0.8964497 ]
# Epoch 272/500, P 0.8334, R 0.8488, F 0.8402, AUC 0.9223
# saved model:  ./model/lstm_273.model
# epoch:274, step:50, loss:1.3819879293441772
# f1 [0.77675841 0.89153046]
# Epoch 273/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9225
# saved model:  ./model/lstm_274.model
# epoch:275, step:50, loss:1.3816931247711182
# f1 [0.7734139  0.88789238]
# Epoch 274/500, P 0.8220, R 0.8433, F 0.8307, AUC 0.9227
# saved model:  ./model/lstm_275.model
# epoch:276, step:50, loss:1.3784905672073364
# f1 [0.78881988 0.89970501]
# Epoch 275/500, P 0.8382, R 0.8517, F 0.8443, AUC 0.9214
# saved model:  ./model/lstm_276.model
# epoch:277, step:50, loss:1.3528271913528442
# f1 [0.78481013 0.9005848 ]
# Epoch 276/500, P 0.8394, R 0.8464, F 0.8427, AUC 0.9205
# saved model:  ./model/lstm_277.model
# epoch:278, step:50, loss:1.36886727809906
# f1 [0.78881988 0.89970501]
# Epoch 277/500, P 0.8382, R 0.8517, F 0.8443, AUC 0.9211
# saved model:  ./model/lstm_278.model
# epoch:279, step:50, loss:1.3434205055236816
# f1 [0.77987421 0.8973607 ]
# Epoch 278/500, P 0.8344, R 0.8435, F 0.8386, AUC 0.9207
# saved model:  ./model/lstm_279.model
# epoch:280, step:50, loss:1.348920464515686
# f1 [0.78395062 0.8964497 ]
# Epoch 279/500, P 0.8334, R 0.8488, F 0.8402, AUC 0.9211
# saved model:  ./model/lstm_280.model
# epoch:281, step:50, loss:1.3345426321029663
# f1 [0.775      0.89411765]
# Epoch 280/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9208
# saved model:  ./model/lstm_281.model
# epoch:282, step:50, loss:1.3320682048797607
# f1 [0.78637771 0.89807976]
# Epoch 281/500, P 0.8358, R 0.8503, F 0.8422, AUC 0.9213
# saved model:  ./model/lstm_282.model
# epoch:283, step:50, loss:1.3367640972137451
# f1 [0.7788162  0.89543446]
# Epoch 282/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9216
# saved model:  ./model/lstm_283.model
# epoch:284, step:50, loss:1.3205360174179077
# f1 [0.77258567 0.89248895]
# Epoch 283/500, P 0.8271, R 0.8391, F 0.8325, AUC 0.9215
# saved model:  ./model/lstm_284.model
# epoch:285, step:50, loss:1.3288177251815796
# f1 [0.77358491 0.89442815]
# Epoch 284/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9209
# saved model:  ./model/lstm_285.model
# epoch:286, step:50, loss:1.3311142921447754
# f1 [0.7788162  0.89543446]
# Epoch 285/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9210
# saved model:  ./model/lstm_286.model
# epoch:287, step:50, loss:1.3198823928833008
# f1 [0.77439024 0.88988095]
# Epoch 286/500, P 0.8242, R 0.8430, F 0.8321, AUC 0.9224
# saved model:  ./model/lstm_287.model
# epoch:288, step:50, loss:1.311712622642517
# f1 [0.77439024 0.88988095]
# Epoch 287/500, P 0.8242, R 0.8430, F 0.8321, AUC 0.9222
# saved model:  ./model/lstm_288.model
# epoch:289, step:50, loss:1.3250322341918945
# f1 [0.77848101 0.89766082]
# Epoch 288/500, P 0.8348, R 0.8417, F 0.8381, AUC 0.9212
# saved model:  ./model/lstm_289.model
# epoch:290, step:50, loss:1.3428748846054077
# f1 [0.78095238 0.89927007]
# Epoch 289/500, P 0.8373, R 0.8432, F 0.8401, AUC 0.9204
# saved model:  ./model/lstm_290.model
# epoch:291, step:50, loss:1.332140326499939
# f1 [0.77675841 0.89153046]
# Epoch 290/500, P 0.8265, R 0.8445, F 0.8341, AUC 0.9229
# saved model:  ./model/lstm_291.model
# epoch:292, step:50, loss:1.295896053314209
# f1 [0.77358491 0.89442815]
# Epoch 291/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9205
# saved model:  ./model/lstm_292.model
# epoch:293, step:50, loss:1.286523461341858
# f1 [0.77602524 0.89604685]
# Epoch 292/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9203
# saved model:  ./model/lstm_293.model
# epoch:294, step:50, loss:1.28647780418396
# f1 [0.77358491 0.89442815]
# Epoch 293/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9202
# saved model:  ./model/lstm_294.model
# epoch:295, step:50, loss:1.3261021375656128
# f1 [0.77358491 0.89442815]
# Epoch 294/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9204
# saved model:  ./model/lstm_295.model
# epoch:296, step:50, loss:1.3106006383895874
# f1 [0.77602524 0.89604685]
# Epoch 295/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9201
# saved model:  ./model/lstm_296.model
# epoch:297, step:50, loss:1.2737716436386108
# f1 [0.77848101 0.89766082]
# Epoch 296/500, P 0.8348, R 0.8417, F 0.8381, AUC 0.9201
# saved model:  ./model/lstm_297.model
# epoch:298, step:50, loss:1.295799732208252
# f1 [0.76307692 0.88592593]
# Epoch 297/500, P 0.8177, R 0.8333, F 0.8245, AUC 0.9219
# saved model:  ./model/lstm_298.model
# epoch:299, step:50, loss:1.2733843326568604
# f1 [0.77602524 0.89604685]
# Epoch 298/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9203
# saved model:  ./model/lstm_299.model
# epoch:300, step:50, loss:1.2896528244018555
# f1 [0.775      0.89411765]
# Epoch 299/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9205
# saved model:  ./model/lstm_300.model
# epoch:301, step:50, loss:1.2793041467666626
# f1 [0.77358491 0.89442815]
# Epoch 300/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9202
# saved model:  ./model/lstm_301.model
# epoch:302, step:50, loss:1.2797527313232422
# f1 [0.7788162  0.89543446]
# Epoch 301/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9202
# saved model:  ./model/lstm_302.model
# epoch:303, step:50, loss:1.2749180793762207
# f1 [0.77602524 0.89604685]
# Epoch 302/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9200
# saved model:  ./model/lstm_303.model
# epoch:304, step:50, loss:1.2739351987838745
# f1 [0.77777778 0.89349112]
# Epoch 303/500, P 0.8290, R 0.8441, F 0.8356, AUC 0.9215
# saved model:  ./model/lstm_304.model
# epoch:305, step:50, loss:1.2960186004638672
# f1 [0.7721519  0.89473684]
# Epoch 304/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9194
# saved model:  ./model/lstm_305.model
# epoch:306, step:50, loss:1.3102415800094604
# f1 [0.775      0.89411765]
# Epoch 305/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9197
# saved model:  ./model/lstm_306.model
# epoch:307, step:50, loss:1.2954834699630737
# f1 [0.775      0.89411765]
# Epoch 306/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9202
# saved model:  ./model/lstm_307.model
# epoch:308, step:50, loss:1.231076955795288
# f1 [0.77358491 0.89442815]
# Epoch 307/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9197
# saved model:  ./model/lstm_308.model
# epoch:309, step:50, loss:1.2962521314620972
# f1 [0.77602524 0.89604685]
# Epoch 308/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9191
# saved model:  ./model/lstm_309.model
# epoch:310, step:50, loss:1.2699540853500366
# f1 [0.7788162  0.89543446]
# Epoch 309/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9197
# saved model:  ./model/lstm_310.model
# epoch:311, step:50, loss:1.2414004802703857
# f1 [0.77602524 0.89604685]
# Epoch 310/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9191
# saved model:  ./model/lstm_311.model
# epoch:312, step:50, loss:1.2211790084838867
# f1 [0.7721519  0.89473684]
# Epoch 311/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9192
# saved model:  ./model/lstm_312.model
# epoch:313, step:50, loss:1.2234125137329102
# f1 [0.7788162  0.89543446]
# Epoch 312/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9206
# saved model:  ./model/lstm_313.model
# epoch:314, step:50, loss:1.2253899574279785
# f1 [0.7788162  0.89543446]
# Epoch 313/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9200
# saved model:  ./model/lstm_314.model
# epoch:315, step:50, loss:1.2770590782165527
# f1 [0.7788162  0.89543446]
# Epoch 314/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9211
# saved model:  ./model/lstm_315.model
# epoch:316, step:50, loss:1.2226771116256714
# f1 [0.7721519  0.89473684]
# Epoch 315/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9188
# saved model:  ./model/lstm_316.model
# epoch:317, step:50, loss:1.2319625616073608
# f1 [0.77602524 0.89604685]
# Epoch 316/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9186
# saved model:  ./model/lstm_317.model
# epoch:318, step:50, loss:1.252229928970337
# f1 [0.775      0.89411765]
# Epoch 317/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9193
# saved model:  ./model/lstm_318.model
# epoch:319, step:50, loss:1.2207064628601074
# f1 [0.76923077 0.88888889]
# Epoch 318/500, P 0.8222, R 0.8380, F 0.8291, AUC 0.9219
# saved model:  ./model/lstm_319.model
# epoch:320, step:50, loss:1.1760369539260864
# f1 [0.77070064 0.89504373]
# Epoch 319/500, P 0.8306, R 0.8353, F 0.8329, AUC 0.9183
# saved model:  ./model/lstm_320.model
# epoch:321, step:50, loss:1.2148146629333496
# f1 [0.775      0.89411765]
# Epoch 320/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9191
# saved model:  ./model/lstm_321.model
# epoch:322, step:50, loss:1.2125037908554077
# f1 [0.77070064 0.89504373]
# Epoch 321/500, P 0.8306, R 0.8353, F 0.8329, AUC 0.9174
# saved model:  ./model/lstm_322.model
# epoch:323, step:50, loss:1.2253155708312988
# f1 [0.775      0.89411765]
# Epoch 322/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9194
# saved model:  ./model/lstm_323.model
# epoch:324, step:50, loss:1.2384796142578125
# f1 [0.77358491 0.89442815]
# Epoch 323/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9188
# saved model:  ./model/lstm_324.model
# epoch:325, step:50, loss:1.2200850248336792
# f1 [0.77358491 0.89442815]
# Epoch 324/500, P 0.8298, R 0.8388, F 0.8340, AUC 0.9191
# saved model:  ./model/lstm_325.model
# epoch:326, step:50, loss:1.247491717338562
# f1 [0.77602524 0.89604685]
# Epoch 325/500, P 0.8323, R 0.8403, F 0.8360, AUC 0.9186
# saved model:  ./model/lstm_326.model
# epoch:327, step:50, loss:1.157084345817566
# f1 [0.775      0.89411765]
# Epoch 326/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9190
# saved model:  ./model/lstm_327.model
# epoch:328, step:50, loss:1.2012521028518677
# f1 [0.7788162  0.89543446]
# Epoch 327/500, P 0.8316, R 0.8438, F 0.8371, AUC 0.9192
# saved model:  ./model/lstm_328.model
# epoch:329, step:50, loss:1.2047197818756104
# f1 [0.77742947 0.89574156]
# Epoch 328/500, P 0.8319, R 0.8420, F 0.8366, AUC 0.9187
# saved model:  ./model/lstm_329.model
# epoch:330, step:50, loss:1.1782770156860352
# f1 [0.775      0.89411765]
# Epoch 329/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9189
# saved model:  ./model/lstm_330.model
# epoch:331, step:50, loss:1.1672283411026
# f1 [0.7721519  0.89473684]
# Epoch 330/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9183
# saved model:  ./model/lstm_331.model
# epoch:332, step:50, loss:1.1938890218734741
# f1 [0.7721519  0.89473684]
# Epoch 331/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9175
# saved model:  ./model/lstm_332.model
# epoch:333, step:50, loss:1.1647919416427612
# f1 [0.7721519  0.89473684]
# Epoch 332/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9171
# saved model:  ./model/lstm_333.model
# epoch:334, step:50, loss:1.2026375532150269
# f1 [0.775      0.89411765]
# Epoch 333/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9187
# saved model:  ./model/lstm_334.model
# epoch:335, step:50, loss:1.18759286403656
# f1 [0.7721519  0.89473684]
# Epoch 334/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9177
# saved model:  ./model/lstm_335.model
# epoch:336, step:50, loss:1.1783174276351929
# f1 [0.77639752 0.89380531]
# Epoch 335/500, P 0.8292, R 0.8424, F 0.8351, AUC 0.9193
# saved model:  ./model/lstm_336.model
# epoch:337, step:50, loss:1.1800472736358643
# f1 [0.775      0.89411765]
# Epoch 336/500, P 0.8295, R 0.8406, F 0.8346, AUC 0.9189
# saved model:  ./model/lstm_337.model
# epoch:338, step:50, loss:1.1553972959518433
# f1 [0.7721519  0.89473684]
# Epoch 337/500, P 0.8302, R 0.8370, F 0.8334, AUC 0.9174
# saved model:  ./model/lstm_338.model
# epoch:339, step:50, loss:1.1437886953353882
# f1 [0.77316294 0.89665211]
# Epoch 338/500, P 0.8332, R 0.8367, F 0.8349, AUC 0.9156
# saved model:  ./model/lstm_339.model
# epoch:340, step:50, loss:1.193994402885437
# f1 [0.77460317 0.89635036]
# Epoch 339/500, P 0.8327, R 0.8385, F 0.8355, AUC 0.9174
# saved model:  ./model/lstm_340.model
# epoch:341, step:50, loss:1.1653602123260498
# f1 [0.77258567 0.89248895]
# Epoch 340/500, P 0.8271, R 0.8391, F 0.8325, AUC 0.9186
# saved model:  ./model/lstm_341.model
# epoch:342, step:50, loss:1.1740201711654663
# f1 [0.77460317 0.89635036]
# Epoch 341/500, P 0.8327, R 0.8385, F 0.8355, AUC 0.9164
# saved model:  ./model/lstm_342.model
# epoch:343, step:50, loss:1.1664000749588013
# f1 [0.77460317 0.89635036]
# Epoch 342/500, P 0.8327, R 0.8385, F 0.8355, AUC 0.9164
# saved model:  ./model/lstm_343.model
# epoch:344, step:50, loss:1.1925033330917358
# f1 [0.77070064 0.89504373]
# Epoch 343/500, P 0.8306, R 0.8353, F 0.8329, AUC 0.9162
# saved model:  ./model/lstm_344.model
# epoch:345, step:50, loss:1.127569317817688
# f1 [0.76971609 0.89311859]
# Epoch 344/500, P 0.8277, R 0.8356, F 0.8314, AUC 0.9168
# saved model:  ./model/lstm_345.model
# epoch:346, step:50, loss:1.1361640691757202
# f1 [0.76971609 0.89311859]
# Epoch 345/500, P 0.8277, R 0.8356, F 0.8314, AUC 0.9196
# saved model:  ./model/lstm_346.model
# epoch:347, step:50, loss:1.149875521659851
# f1 [0.76971609 0.89311859]
# Epoch 346/500, P 0.8277, R 0.8356, F 0.8314, AUC 0.9213
# saved model:  ./model/lstm_347.model
